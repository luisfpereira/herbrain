# %%
import pprint

import numpy as np
import polpo.preprocessing.dict as ppdict
import polpo.preprocessing.pd as ppd
from polpo.model_eval import (
    MultiEvaluator,
    OlsPValues,
    R2Score,
    ReconstructionError,
    VertexReconstructionError,
)
from polpo.models import MultiTransform, SupervisedXEmbeddingRegressor
from polpo.preprocessing import (
    IndexMap,
    Map,
    NestingSwapper,
    PartiallyInitializedStep,
)
from polpo.preprocessing.load.pregnancy import (
    NeuroMaternalMeshLoader,
    NeuroMaternalTabularDataLoader,
)
from polpo.preprocessing.mesh.conversion import PvFromData, ToVertices
from polpo.preprocessing.mesh.io import FreeSurferReader
from polpo.preprocessing.mesh.registration import PvAlign
from polpo.preprocessing.mri import segmtool2encoding
from polpo.sklearn.adapter import EvaluatedModel
from sklearn.cross_decomposition import PLSRegression
from sklearn.linear_model import LinearRegression
# Out:
# [KeOps] Warning : cuda was detected, but driver API could not be initialized. Switching to cpu only.

# %%
DEBUG = False

FULL_DEBUG = False and DEBUG

# %% [markdown]
# EDS.

# %%
pipe = NeuroMaternalTabularDataLoader(
    keep_mothers=True,
    keep_control=False,
)

tab_data = pipe()

# %%
eds_pipe = (
    ppd.DfFilter(lambda df: df["ses"] == 1)
    + ppd.IndexSetter("participant_id", drop=True)
    + ppd.ColumnsSelector("EDS.Total")
    + ppd.SeriesToDict()
)

eds_dict = eds_pipe(tab_data)

eds_dict;

# %% [markdown]
# Meshes and vector fields.

# %%
if FULL_DEBUG:
    structs = ["L_Hipp", "R_Hipp"]
else:
    encoding = segmtool2encoding("fsl")
    structs = encoding.structs
    structs.remove("BrStem")


n_structs = len(structs)

as_dict = False
file_finder = NeuroMaternalMeshLoader(as_dict=as_dict)

Map_ = ppdict.DictMap if as_dict else Map


mesh_reader = ppdict.DictMap(Map_(FreeSurferReader() + PvFromData()))

prep_pipe = PartiallyInitializedStep(
    Step=lambda **kwargs: ppdict.DictMap(Map_(PvAlign(**kwargs))),
    # NB: aligns against first subject, t_0
    _target=lambda meshes: meshes[list(meshes.keys())[0]][0],
    max_iterations=500,
)


if DEBUG:
    # because alignment is slow
    per_struct_pipe = mesh_reader
else:
    per_struct_pipe = mesh_reader + prep_pipe


pipe = ppdict.HashWithIncoming(
    Map(
        PartiallyInitializedStep(
            Step=NeuroMaternalMeshLoader,
            as_dict=False,
            pass_data=False,
            _struct=lambda name: name.split("_")[-1],
            _left=lambda name: name.split("_")[0] == "L",
            derivative="enigma",
        )
    )
) + ppdict.DictMap(per_struct_pipe)

structs_dict = pipe(structs)

structs
# Out:
# ['L_Thal',
#  'R_Thal',
#  'L_Caud',
#  'R_Caud',
#  'L_Puta',
#  'R_Puta',
#  'L_Pall',
#  'R_Pall',
#  'L_Hipp',
#  'R_Hipp',
#  'L_Amyg',
#  'R_Amyg',
#  'L_Accu',
#  'R_Accu']

# %%
meshes2flat_vfields = ppdict.DictMap(
    step=Map(ToVertices()) + (lambda verts: (verts[1] - verts[0]).flatten())
)
structs2flat_vfields = ppdict.DictMap(meshes2flat_vfields)

structs_flat_vfields_dict = structs2flat_vfields(structs_dict)

len(structs_flat_vfields_dict)
# Out:
# 14

# %%
dataset_pipe = (
    IndexMap(index=0, step=ppdict.NestedDictSwapper())
    + ppdict.DictMerger()
    + NestingSwapper()
    + IndexMap(index=0, step=ppdict.ListDictSwapper())
    + IndexMap(index=0, step=ppdict.DictMap(lambda x: np.stack(x)))
    + IndexMap(index=1, step=lambda x: np.stack(x)[:, None])
)


structs_flat_vfields, eds = dataset_pipe([structs_flat_vfields_dict, eds_dict])

flat_vfields = (ppdict.DictToValuesList() + (lambda x: np.concatenate(x, axis=-1)))(
    structs_flat_vfields
)

len(structs_flat_vfields), flat_vfields.shape, eds.shape
# Out:
# (14, (117, 81360), (117, 1))

# %%
model = EvaluatedModel(
    SupervisedXEmbeddingRegressor(
        MultiTransform(
            [
                EvaluatedModel(
                    PLSRegression(n_components=1),
                    MultiEvaluator(
                        [
                            ReconstructionError(),
                            VertexReconstructionError(prefix="vertex"),
                        ]
                    ),
                )
                for _ in range(n_structs)
            ],
            dim=[vertices.shape[-1] for vertices in structs_flat_vfields.values()],
        ),
        EvaluatedModel(
            LinearRegression(),
            MultiEvaluator([OlsPValues(), R2Score()]),
        ),
    ),
    R2Score(),
)

model
# Out:
# SupervisedXEmbeddingRegressor(encoder=MultiTransform(dim=[7506, 7506, 7506,
#                                                           7506, 7506, 7506,
#                                                           3762, 3762, 7506,
#                                                           7506, 4104, 4104,
#                                                           2790, 2790],
#                                                      transforms=[<polpo.sklearn.adapter.EvaluatedModel object at 0x73dc72001af0>,
#                                                                  <polpo.sklearn.adapter.EvaluatedModel object at 0x73dc72001dc0>,
#                                                                  <polpo.sklearn.adapter.EvaluatedModel object at 0x73dc72001940>,
#                                                                  <polpo.sklearn.adapter.Eva...
#                                                                  <polpo.sklearn.adapter.EvaluatedModel object at 0x73dc72002600>,
#                                                                  <polpo.sklearn.adapter.EvaluatedModel object at 0x73dc72002870>,
#                                                                  <polpo.sklearn.adapter.EvaluatedModel object at 0x73dc720029c0>,
#                                                                  <polpo.sklearn.adapter.EvaluatedModel object at 0x73dc72002a50>,
#                                                                  <polpo.sklearn.adapter.EvaluatedModel object at 0x73dc72002c60>]),
#                               regressor=<polpo.sklearn.adapter.EvaluatedModel object at 0x73dc72002c90>)

# %%
X, y = flat_vfields, eds

model.fit(X, y)
# Out:
# SupervisedXEmbeddingRegressor(encoder=MultiTransform(dim=[7506, 7506, 7506,
#                                                           7506, 7506, 7506,
#                                                           3762, 3762, 7506,
#                                                           7506, 4104, 4104,
#                                                           2790, 2790],
#                                                      transforms=[<polpo.sklearn.adapter.EvaluatedModel object at 0x73dc72001af0>,
#                                                                  <polpo.sklearn.adapter.EvaluatedModel object at 0x73dc72001dc0>,
#                                                                  <polpo.sklearn.adapter.EvaluatedModel object at 0x73dc72001940>,
#                                                                  <polpo.sklearn.adapter.Eva...
#                                                                  <polpo.sklearn.adapter.EvaluatedModel object at 0x73dc72002600>,
#                                                                  <polpo.sklearn.adapter.EvaluatedModel object at 0x73dc72002870>,
#                                                                  <polpo.sklearn.adapter.EvaluatedModel object at 0x73dc720029c0>,
#                                                                  <polpo.sklearn.adapter.EvaluatedModel object at 0x73dc72002a50>,
#                                                                  <polpo.sklearn.adapter.EvaluatedModel object at 0x73dc72002c60>]),
#                               regressor=<polpo.sklearn.adapter.EvaluatedModel object at 0x73dc72002c90>)

# %% [markdown]
# Eval results of full pipeline.

# %%
model.eval_result_
# Out:
# {'r2': array([0.62420661])}

# %% [markdown]
# Eval results of inner regression (PLS component -> EDS).

# %%
model.regressor_.eval_result_
# Out:
# {'mse': array([9.03188904]),
#  'res_var': array([10.36010802]),
#  'std_err': array([[0.19154738, 0.17478454, 0.32074219, 0.40455368, 0.21538441,
#          0.31696358, 0.17442715, 0.26581885, 0.17805295, 0.22533223,
#          0.5376841 , 0.34254519, 0.20837282, 0.15122466]]),
#  't': array([[2.99686012, 2.33440686, 2.0824051 , 2.05395643, 1.9897186 ,
#          0.91474212, 3.04647361, 1.40236645, 2.32474417, 2.18004121,
#          0.26575589, 0.81488543, 2.45572263, 3.9397964 ]]),
#  'pvals': array([[3.42544680e-03, 2.15343319e-02, 3.98075053e-02, 4.25376817e-02,
#          4.92988243e-02, 3.62484419e-01, 2.94759675e-03, 1.63842042e-01,
#          2.20671305e-02, 3.15542139e-02, 7.90963624e-01, 4.17036487e-01,
#          1.57504969e-02, 1.49478976e-04]]),
#  'adj-pvals': array([[0.04795626, 0.30148065, 0.55730507, 0.59552754, 0.69018354,
#          1.        , 0.04126635, 1.        , 0.30893983, 0.441759  ,
#          1.        , 1.        , 0.22050696, 0.00209271]]),
#  'r2': array([0.62420661])}

# %% [markdown]
# Eval results of PLS reconstruction.

# %%
for struct, transform in zip(structs, model.encoder_.transforms_):
    print(f"{struct}:")
    pprint.pprint(transform.eval_result_)
# Out:
# L_Thal:
# {'featurewise_rec_error': array([18.31822995, 14.22728718,  8.16419056, ..., 16.63549312,
#        26.16067045,  8.41252593], shape=(7506,)),
#  'rec_error_mse': np.float64(0.10510561075719327),
#  'rec_error_sum': np.float64(92303.95757818864),
#  'vertex-rec_error_mse': np.float64(0.31531683227157986),
#  'vertex-rec_error_sum': np.float64(92303.95757818867),
#  'vertex-vertexwise_rec_error': array([40.70970769, 40.83687244, 40.07225108, ..., 47.35045991,
#        54.5758885 , 51.2086895 ], shape=(2502,))}
# R_Thal:
# {'featurewise_rec_error': array([16.93917036, 20.66090719,  6.78192553, ..., 12.57705357,
#        22.38586751,  8.31401847], shape=(7506,)),
#  'rec_error_mse': np.float64(0.09595917337096085),
#  'rec_error_sum': np.float64(84271.53797272456),
#  'vertex-rec_error_mse': np.float64(0.28787752011288253),
#  'vertex-rec_error_sum': np.float64(84271.53797272456),
#  'vertex-vertexwise_rec_error': array([44.38200308, 48.01309585, 45.81793757, ..., 37.89910737,
#        44.95512191, 43.27693955], shape=(2502,))}
# L_Caud:
# {'featurewise_rec_error': array([42.048677  , 54.6297778 , 25.88738465, ..., 13.82462295,
#        52.28353948, 16.21368377], shape=(7506,)),
#  'rec_error_mse': np.float64(0.1636794710701109),
#  'rec_error_sum': np.float64(143743.63885271354),
#  'vertex-rec_error_mse': np.float64(0.49103841321033265),
#  'vertex-rec_error_sum': np.float64(143743.6388527135),
#  'vertex-vertexwise_rec_error': array([122.56583944, 105.75210678, 133.05470195, ...,  82.04878422,
#         82.05831252,  82.3218462 ], shape=(2502,))}
# R_Caud:
# {'featurewise_rec_error': array([37.10437978, 80.13797928, 58.38190096, ..., 13.3589712 ,
#        28.10717027, 16.03264841], shape=(7506,)),
#  'rec_error_mse': np.float64(0.13285315410345194),
#  'rec_error_sum': np.float64(116671.9056399597),
#  'vertex-rec_error_mse': np.float64(0.3985594623103559),
#  'vertex-rec_error_sum': np.float64(116671.90563995972),
#  'vertex-vertexwise_rec_error': array([175.62426002, 174.3108953 , 125.1882102 , ...,  61.85977484,
#         55.48928184,  57.49878988], shape=(2502,))}
# L_Puta:
# {'featurewise_rec_error': array([ 7.21865843, 26.1005559 , 22.0376332 , ..., 27.20082148,
#        68.07619945,  9.57348013], shape=(7506,)),
#  'rec_error_mse': np.float64(0.14038352950638985),
#  'rec_error_sum': np.float64(123285.09637957058),
#  'vertex-rec_error_mse': np.float64(0.4211505885191697),
#  'vertex-rec_error_sum': np.float64(123285.09637957062),
#  'vertex-vertexwise_rec_error': array([ 55.35684753,  58.91216761,  56.35654117, ...,  95.04405539,
#         98.55212714, 104.85050106], shape=(2502,))}
# R_Puta:
# {'featurewise_rec_error': array([11.75748504, 46.002378  , 15.05225564, ..., 16.79519679,
#        16.72056698, 11.99972788], shape=(7506,)),
#  'rec_error_mse': np.float64(0.09138754427836576),
#  'rec_error_sum': np.float64(80256.72416034937),
#  'vertex-rec_error_mse': np.float64(0.2741626328350973),
#  'vertex-rec_error_sum': np.float64(80256.72416034937),
#  'vertex-vertexwise_rec_error': array([72.81211867, 73.92590113, 69.41494198, ..., 45.59106127,
#        46.7633918 , 45.51549165], shape=(2502,))}
# L_Pall:
# {'featurewise_rec_error': array([11.81454757, 69.93937057, 29.01285172, ..., 44.12014736,
#        17.33171574, 21.01460532], shape=(3762,)),
#  'rec_error_mse': np.float64(0.16442997755994035),
#  'rec_error_sum': np.float64(72374.51234291798),
#  'vertex-rec_error_mse': np.float64(0.493289932679821),
#  'vertex-rec_error_sum': np.float64(72374.51234291798),
#  'vertex-vertexwise_rec_error': array([110.76676987, 112.02844751, 112.25574221, ...,  84.64980041,
#         80.63628752,  82.46646842], shape=(1254,))}
# R_Pall:
# {'featurewise_rec_error': array([ 9.44121189, 45.96738617, 19.34419083, ..., 21.32131617,
#        14.11532254,  6.5116064 ], shape=(3762,)),
#  'rec_error_mse': np.float64(0.10510419915239112),
#  'rec_error_sum': np.float64(46262.03367372156),
#  'vertex-rec_error_mse': np.float64(0.31531259745717344),
#  'vertex-rec_error_sum': np.float64(46262.03367372157),
#  'vertex-vertexwise_rec_error': array([74.75278889, 79.5281986 , 78.36565683, ..., 40.60192055,
#        40.64306188, 41.94824511], shape=(1254,))}
# L_Hipp:
# {'featurewise_rec_error': array([15.98668262, 18.99377637,  7.75389366, ..., 49.69924518,
#        33.52541568, 13.12929494], shape=(7506,)),
#  'rec_error_mse': np.float64(0.12620146380654473),
#  'rec_error_sum': np.float64(110830.3779178352),
#  'vertex-rec_error_mse': np.float64(0.37860439141963415),
#  'vertex-rec_error_sum': np.float64(110830.37791783518),
#  'vertex-vertexwise_rec_error': array([ 42.73435265,  42.4259018 ,  44.43781958, ...,  94.40772419,
#        101.50874104,  96.3539558 ], shape=(2502,))}
# R_Hipp:
# {'featurewise_rec_error': array([17.9791545 , 18.60536418,  7.58733091, ..., 26.67329744,
#        20.69811078, 16.13905476], shape=(7506,)),
#  'rec_error_mse': np.float64(0.09753179870730835),
#  'rec_error_sum': np.float64(85652.62068835562),
#  'vertex-rec_error_mse': np.float64(0.292595396121925),
#  'vertex-rec_error_sum': np.float64(85652.62068835559),
#  'vertex-vertexwise_rec_error': array([44.17184959, 48.73960119, 41.6668027 , ..., 63.68531738,
#        64.18668224, 63.51046298], shape=(2502,))}
# L_Amyg:
# {'featurewise_rec_error': array([268.72985423,  34.76871231,  84.27472173, ..., 309.4771224 ,
#         47.5585429 ,  76.27300903], shape=(4104,)),
#  'rec_error_mse': np.float64(0.7653123478820666),
#  'rec_error_sum': np.float64(367478.49945783615),
#  'vertex-rec_error_mse': np.float64(2.2959370436461994),
#  'vertex-rec_error_sum': np.float64(367478.4994578361),
#  'vertex-vertexwise_rec_error': array([387.77328827, 379.33444985, 390.36719886, ..., 447.02124702,
#        451.40213539, 433.30867432], shape=(1368,))}
# R_Amyg:
# {'featurewise_rec_error': array([14.60376518, 12.85765147, 19.52303679, ..., 44.32994854,
#        19.39626571, 10.87599258], shape=(4104,)),
#  'rec_error_mse': np.float64(0.11961449566697299),
#  'rec_error_sum': np.float64(57435.05315541909),
#  'vertex-rec_error_mse': np.float64(0.358843487000919),
#  'vertex-rec_error_sum': np.float64(57435.05315541909),
#  'vertex-vertexwise_rec_error': array([46.98445345, 45.76205176, 47.52750387, ..., 78.84210457,
#        78.55589105, 74.60220683], shape=(1368,))}
# L_Accu:
# {'featurewise_rec_error': array([15.67911992, 11.13917615, 15.60476297, ..., 11.50500189,
#         7.20107022,  7.92686312], shape=(2790,)),
#  'rec_error_mse': np.float64(0.09248083092522667),
#  'rec_error_sum': np.float64(30188.51763892174),
#  'vertex-rec_error_mse': np.float64(0.27744249277567995),
#  'vertex-rec_error_sum': np.float64(30188.517638921734),
#  'vertex-vertexwise_rec_error': array([42.42305903, 44.75889097, 39.06098889, 41.01181929, 36.85074506,
#        43.41028423, 46.30641962, 39.27205093, 48.61341147, 34.08299466,
#        30.46391471, 44.48040556, 39.89254716, 34.17599192, 28.25717258,
#        37.65350418, 35.51596802, 36.1926857 , 25.7364032 , 30.0011269 ,
#        33.78604734, 35.43961985, 26.14572326, 29.58734925, 34.42417234,
#        36.01185769, 34.66250937, 39.84904934, 37.18741469, 36.44517361,
#        47.03891634, 50.14771862, 35.61601689, 29.0404597 , 51.54958012,
#        27.05178583, 26.72089321, 46.50653462, 23.68904889, 22.96044683,
