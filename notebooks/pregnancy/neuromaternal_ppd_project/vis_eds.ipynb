# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from polpo.preprocessing.load.pregnancy import (
    NeuroMaternalTabularDataLoader,
)

# %%
pipe = NeuroMaternalTabularDataLoader(
    keep_mothers=True,
    keep_control=False,
)

df = pipe()

df
# Out:
#     participant_id  ses   group  WAIS.Total  PSQI.Total  PSS.Total  EDS.Total  \
# 0       049ab1a591    0  mother        22.0         9.0       12.0        4.0
# 1       049ab1a591    1  mother         NaN         7.0       20.0        2.0
# 5       082dc070c1    0  mother        21.0        14.0       22.0       14.0
# 6       082dc070c1    1  mother         NaN         9.0       33.0       12.0
# 8       085a9ee2fc    0  mother        26.0         6.0        9.0        2.0
# ..             ...  ...     ...         ...         ...        ...        ...
# 398     facd54026a    1  mother         NaN        13.0       25.0        7.0
# 400     fb91476aa2    0  mother        30.0         1.0        8.0        3.0
# 401     fb91476aa2    1  mother         NaN        10.0       17.0        4.0
# 405     ff91cacb30    0  mother        26.0         3.0        9.0        2.0
# 406     ff91cacb30    1  mother         NaN         2.0       10.0        0.0
#
#      MAS.Total  PRAS.Total  ParentalStressScale.Total  BEQ.Total  age.years  \
# 0         71.0        66.0                        NaN        NaN  34.349076
# 1         85.0         NaN                       27.0        3.3  34.480493
# 5         59.0        82.0                        NaN        NaN  35.780972
# 6         70.0         NaN                       37.0        3.2  35.937029
# 8         77.0        42.0                        NaN        NaN  34.902122
# ..         ...         ...                        ...        ...        ...
# 398       79.0         NaN                       42.0        3.3  39.329227
# 400       61.0        49.0                        NaN        NaN  31.060917
# 401       76.0         NaN                       23.0        2.2  31.249829
# 405       80.0        51.0                        NaN        NaN  30.959617
# 406       88.0         NaN                       18.0        2.7  31.074606
#
#      intersession.days.ses.3  postpartum.days  T1w  highres_T2w
# 0                          0            -27.0    1            1
# 1                         48             21.0    1            1
# 5                          0            -38.0    1            1
# 6                         57             19.0    1            1
# 8                          0            -31.0    1            1
# ..                       ...              ...  ...          ...
# 398                       69             43.0    1            1
# 400                        0            -31.0    1            1
# 401                       69             38.0    1            1
# 405                        0            -33.0    1            1
# 406                       42              9.0    1            1
#
# [235 rows x 16 columns]

# %%
val = 10.0
var = "EDS.Total"

counts = [(df[var] < val).sum(), (df[var] >= val).sum()]

plt.bar(["< {}".format(val), "≥ {}".format(val)], counts)
plt.xlabel("EDS")
plt.ylabel("Count")

plt.show()

# %%
ax = df[var].hist(grid=False)

ax.set_xlabel("EDS")
ax.set_ylabel("Count")

ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
